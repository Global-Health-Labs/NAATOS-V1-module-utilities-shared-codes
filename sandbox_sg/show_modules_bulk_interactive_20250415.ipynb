# %% [markdown]
# NAATOS Bulk Analysis Tool for Modules
# ============
#
# Simon Ghionea, Started 3/17/2025
#
# This notebook focuses on data from Quantigen

# %% [markdown]
# ## Imports

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import xarray as xr
import math
import time

import plotly.express as px
import panel as pn
import param

import naatos_module_tools.logreader as logreader
import naatos_module_tools.logprocessors as logprocessors
import naatos_module_tools.logplotter as logplotter

# %%
pn.extension("plotly")
pn.extension("tabulator")
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='3a189ee8-0920-413e-a6f5-e3072da1f54e'>
#   <div id="ec7c2b89-7eb8-45cb-b6ab-bb8ac2621dbf" data-root-id="3a189ee8-0920-413e-a6f5-e3072da1f54e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"6a755fb2-413b-482b-bb94-a86dbb47fd87":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"3a189ee8-0920-413e-a6f5-e3072da1f54e"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"4560bbea-54ec-4cf9-af70-ff109b9827d4","attributes":{"plot_id":"3a189ee8-0920-413e-a6f5-e3072da1f54e","comm_id":"4f72d3f1e8474f3f963a6b6cd20c54b5","client_comm_id":"a1b8b9cc27714e9682235930fe454c97"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"6a755fb2-413b-482b-bb94-a86dbb47fd87","roots":{"3a189ee8-0920-413e-a6f5-e3072da1f54e":"ec7c2b89-7eb8-45cb-b6ab-bb8ac2621dbf"},"root_ids":["3a189ee8-0920-413e-a6f5-e3072da1f54e"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Plotly !== undefined) && ( root.Plotly !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Enumerate, Select Experiment Folders, Load All Data

# %%
#root = r'C:\Users\SimonGhionea\Global Health Labs, Inc\NAATOS Product Feasibility - General - Internal - Electronic Control Module\Beta design\PowermoduleTestData\by_exp'
root = r'C:\Users\SimonGhionea\Global Health Labs, Inc\NAATOS Product Feasibility - General - Internal - Electronic Control Module\Beta design\SamplePrepTestData\by_exp'
#root = r'C:\Temp\NAATOS_MODULE_AUTODOWNLOADS'
rootpath = Path(root)

experiment_list = [x.name for x in rootpath.iterdir() if x.is_dir()];

experiments_to_plot = [
    #'20250128_sgdev_3.1',
    #'20250128_sgdev_3.1_b_abridge_pwmbugsearch',
    #'20250128_sgdev_3.1_c_abridge_diffpid',
    #'20250128_sgdev_3.1_d_2cycle_emulate',
    
    #'20250225_sgdev_cooldown_test',
    #'20250228_sgdev_cooldown_test',

    #'20250311_DX_download',
    #'20250404_PM_fromDX',
    '20250410_CoDxQuantigen_failunit',
    
    # '20250310_SimonGhionea_autodl',
    # '20250311_SimonGhionea_autodl',
    #'20250312_SimonGhionea_autodl',
    #'20250313_SimonGhionea_autodl_PM_eelab_continuous',
    #'20250317_SimonGhionea_autodl',
]

experiments_to_plot = [x for x in experiments_to_plot if x in experiment_list]

print('Found experiment folders:',experiments_to_plot)
# Out:
# Found experiment folders: ['20250410_CoDxQuantigen_failunit']

# %%
#%% Load associated datafile from the unit-logged run
# logfile = logfilenames[0];
# df_in,df_events = logreader.scanALogfile(logfile)
dfraw = logreader.processRootFolder(rootpath,experiments_to_plot);
df_events = dfraw[ ~dfraw['Event'].isnull() & ~(dfraw['Event']==' ') ]
# Out:
# Processing rootfolder C:\Users\SimonGhionea\Global Health Labs, Inc\NAATOS Product Feasibility - General - Internal - Electronic Control Module\Beta design\SamplePrepTestData\by_exp
# Experiment 20250410_CoDxQuantigen_failunit
# The folder we will assume each folder are UNITS
# folder "SP46"
# ['config', 'logs']
# Folder logs
# Done loading log sample_02-05-25_112823.csv
# Done loading log sample_02-05-25_113645.csv
# Done loading log sample_02-05-25_113655.csv
# Done loading log sample_02-05-25_113743.csv
# Done loading log sample_02-05-25_114342.csv
# Done loading log sample_02-05-25_114346.csv
# Done loading log sample_02-06-25_082044.csv
# Done loading log sample_02-06-25_083033.csv
# Done loading log sample_02-06-25_083950.csv
# Done loading log sample_02-06-25_084853.csv
# Done loading log sample_02-06-25_085743.csv
# Done loading log sample_02-06-25_090649.csv
# Done loading log sample_02-06-25_091621.csv
# Done loading log sample_02-06-25_092547.csv
# Done loading log sample_02-06-25_093504.csv
# Done loading log sample_02-06-25_094430.csv
# Done loading log sample_02-06-25_095414.csv
# Done loading log sample_02-06-25_100339.csv
# Done loading log sample_02-11-25_101645.csv
# Done loading log sample_02-11-25_102603.csv
# Done loading log sample_02-11-25_103523.csv
# Done loading log sample_02-11-25_104435.csv
# Done loading log sample_02-11-25_105359.csv
# Done loading log sample_02-12-25_055351.csv
# Done loading log sample_02-12-25_060332.csv
# Done loading log sample_02-12-25_061301.csv
# Done loading log sample_02-12-25_062207.csv
# Done loading log sample_02-12-25_063111.csv
# Done loading log sample_02-12-25_064025.csv
# Done loading log sample_02-12-25_064929.csv
# Done loading log sample_02-12-25_065818.csv
# file sample_02-12-25_070717.csv had 1 rows with bad times, we will use prior time
# Done loading log sample_02-12-25_070717.csv
# Done loading log sample_02-12-25_071611.csv
# Done loading log sample_02-12-25_072513.csv
# Done loading log sample_02-12-25_073407.csv
# Done loading log sample_02-12-25_074314.csv
# Done loading log sample_02-12-25_075218.csv
# Done loading log sample_02-12-25_080120.csv
# Done loading log sample_02-12-25_081019.csv
# Done loading log sample_02-12-25_081920.csv
# Done loading log sample_02-12-25_082814.csv
# Done loading log sample_02-12-25_083732.csv
# Done loading log sample_02-12-25_084659.csv
# Done loading log sample_02-12-25_085555.csv
# Done loading log sample_02-12-25_090455.csv
# Done loading log sample_02-12-25_091347.csv
# Done loading log sample_02-12-25_092251.csv
# Done loading log sample_02-12-25_093150.csv
# Done loading log sample_02-12-25_094045.csv
# Done loading log sample_02-12-25_094939.csv
# Done loading log sample_02-12-25_095845.csv
# Done loading log sample_02-12-25_100759.csv
# Done loading log sample_02-12-25_101701.csv
# Done loading log sample_02-12-25_102836.csv
# Done loading log sample_02-12-25_105038.csv
# Done loading log sample_02-12-25_110001.csv
# Done loading log sample_02-12-25_110902.csv
# Done loading log sample_02-12-25_111805.csv
# file sample_02-17-25_071401.csv had 1 rows with bad times, we will use prior time
# file sample_02-17-25_071401.csv had a bad time in first row, use the next
# Done loading log sample_02-17-25_071401.csv
# Done loading log sample_02-17-25_072320.csv
# Done loading log sample_02-17-25_073217.csv
# Done loading log sample_02-17-25_074111.csv
# Done loading log sample_02-17-25_075009.csv
# Done loading log sample_02-17-25_075912.csv
# Done loading log sample_02-17-25_080806.csv
# Done loading log sample_02-17-25_081706.csv
# Done loading log sample_02-17-25_082600.csv
# Done loading log sample_02-17-25_083500.csv
# Done loading log sample_02-18-25_064547.csv
# Done loading log sample_02-18-25_065856.csv
# Done loading log sample_02-18-25_070831.csv
# Done loading log sample_02-18-25_071817.csv
# Done loading log sample_02-18-25_073011.csv
# Done loading log sample_02-18-25_073915.csv
# Done loading log sample_02-18-25_074815.csv
# Done loading log sample_02-18-25_075708.csv
# Done loading log sample_02-18-25_080606.csv
# Done loading log sample_02-18-25_081505.csv
# Done loading log sample_02-19-25_060624.csv
# Done loading log sample_02-19-25_061625.csv
# Done loading log sample_02-19-25_062545.csv
# Done loading log sample_02-19-25_063458.csv
# Done loading log sample_02-19-25_064351.csv
# Done loading log sample_02-19-25_065244.csv
# Done loading log sample_02-19-25_070139.csv
# Done loading log sample_02-19-25_071035.csv
# Done loading log sample_02-19-25_071931.csv
# Done loading log sample_02-19-25_072827.csv
# Done loading log sample_02-19-25_073729.csv
# Done loading log sample_02-19-25_074630.csv
# file sample_02-19-25_075539.csv had 1 rows with bad times, we will use prior time
# Done loading log sample_02-19-25_075539.csv
# Done loading log sample_02-19-25_080435.csv
# Done loading log sample_02-19-25_081335.csv
# Done loading log sample_02-19-25_082320.csv
# Done loading log sample_02-19-25_083220.csv
# Done loading log sample_02-19-25_084130.csv
# Done loading log sample_02-19-25_085020.csv
# Done loading log sample_02-19-25_085912.csv
# Done loading log sample_02-19-25_090810.csv
# Done loading log sample_02-19-25_091657.csv
# Done loading log sample_02-19-25_092552.csv
# Done loading log sample_02-19-25_093454.csv
# Done loading log sample_02-19-25_094403.csv
# Done loading log sample_02-19-25_095301.csv
# Done loading log sample_02-19-25_100206.csv
# Done loading log sample_02-19-25_101108.csv
# Done loading log sample_02-19-25_102008.csv
# Done loading log sample_02-19-25_102913.csv
# Done loading log sample_02-19-25_103817.csv
# Done loading log sample_02-19-25_104723.csv
# Done loading log sample_02-19-25_105615.csv
# Done loading log sample_02-19-25_110513.csv
# Done loading log sample_02-19-25_111404.csv
# Done loading log sample_03-03-25_075730.csv
# Done loading log sample_03-03-25_080643.csv
# Done loading log sample_03-03-25_081549.csv
# Done loading log sample_03-03-25_082454.csv
# Done loading log sample_03-03-25_083403.csv
# Done loading log sample_03-03-25_084302.csv
# Done loading log sample_03-03-25_085157.csv
# Done loading log sample_03-18-25_085622.csv
# Done loading log sample_03-18-25_090537.csv
# Done loading log sample_03-18-25_091441.csv
# Done loading log sample_03-18-25_092344.csv
# Done loading log sample_03-18-25_093243.csv
# Done loading log sample_03-18-25_095806.csv
# Done loading log sample_03-18-25_100839.csv
# Done loading log sample_03-20-25_070550.csv
# Done loading log sample_03-20-25_071503.csv
# Done loading log sample_03-20-25_072404.csv
# Done loading log sample_03-20-25_073304.csv
# Done loading log sample_03-20-25_074215.csv
# Done loading log sample_04-08-25_082032.csv
# Done loading log sample_04-08-25_083406.csv
# File sample_04-08-25_102003.csv had zero-size! Ignoring
# Skipped log sample_04-08-25_102003.csv
# folder "SP53"
# ['config', 'logs']
# Folder logs
# Done loading log sample_01-01-00_000204.csv
# Done loading log sample_01-01-00_000230.csv
# Done loading log sample_01-01-00_001449.csv
# Done loading log sample_01-19-00_094841.csv
# Done loading log sample_01-19-00_094844.csv
# Done loading log sample_01-19-00_094858.csv
# Done loading log sample_01-28-25_165255.csv
# Done loading log sample_01-28-25_170309.csv
# Done loading log sample_01-30-25_160054.csv
# Done loading log sample_01-30-25_160100.csv
# Done loading log sample_01-30-25_160209.csv
# Done loading log sample_02-05-25_112920.csv
# Done loading log sample_02-05-25_113133.csv
# Done loading log sample_02-05-25_113459.csv
# Done loading log sample_02-06-25_082050.csv
# Done loading log sample_02-06-25_083039.csv
# Done loading log sample_02-06-25_083956.csv
# Done loading log sample_02-06-25_084859.csv
# Done loading log sample_02-06-25_085750.csv
# Done loading log sample_02-06-25_090654.csv
# Done loading log sample_02-06-25_091627.csv
# Done loading log sample_02-06-25_092553.csv
# Done loading log sample_02-06-25_093510.csv
# Done loading log sample_02-06-25_094436.csv
# Done loading log sample_02-06-25_095421.csv
# Done loading log sample_02-06-25_100346.csv
# Done loading log sample_02-11-25_101651.csv
# Done loading log sample_02-11-25_102610.csv
# Done loading log sample_02-11-25_103529.csv
# Done loading log sample_02-11-25_104441.csv
# Done loading log sample_02-11-25_105405.csv
# Done loading log sample_02-12-25_055357.csv
# Done loading log sample_02-12-25_060339.csv
# Done loading log sample_02-12-25_061308.csv
# Done loading log sample_02-12-25_062213.csv
# Done loading log sample_02-12-25_063119.csv
# Done loading log sample_02-12-25_064032.csv
# Done loading log sample_02-12-25_064936.csv
# Done loading log sample_02-12-25_065825.csv
# Done loading log sample_02-12-25_070724.csv
# Done loading log sample_02-12-25_071618.csv
# Done loading log sample_02-12-25_072519.csv
# Done loading log sample_02-12-25_073413.csv
# Done loading log sample_02-12-25_074320.csv
# Done loading log sample_02-12-25_075225.csv
# Done loading log sample_02-12-25_080127.csv
# Done loading log sample_02-12-25_081027.csv
# Done loading log sample_02-12-25_081928.csv
# Done loading log sample_02-12-25_082821.csv
# Done loading log sample_02-12-25_083739.csv
# Done loading log sample_02-12-25_084705.csv
# Done loading log sample_02-12-25_085601.csv
# Done loading log sample_02-12-25_090502.csv
# Done loading log sample_02-12-25_091353.csv
# Done loading log sample_02-12-25_092257.csv
# file sample_02-12-25_093156.csv had 1 rows with bad times, we will use prior time
# Done loading log sample_02-12-25_093156.csv
# Done loading log sample_02-12-25_094052.csv
# Done loading log sample_02-12-25_094945.csv
# Done loading log sample_02-12-25_095852.csv
# Done loading log sample_02-12-25_100805.csv
# Done loading log sample_02-12-25_101708.csv
# Done loading log sample_02-12-25_102843.csv
# Done loading log sample_02-12-25_105045.csv
# Done loading log sample_02-12-25_110009.csv
# Done loading log sample_02-12-25_110910.csv
# Done loading log sample_02-12-25_111813.csv
# Done loading log sample_02-17-25_071404.csv
# Done loading log sample_02-17-25_072328.csv
# Done loading log sample_02-17-25_073224.csv
# Done loading log sample_02-17-25_074118.csv
# Done loading log sample_02-17-25_075017.csv
# Done loading log sample_02-17-25_075919.csv
# Done loading log sample_02-17-25_080813.csv
# Done loading log sample_02-17-25_081713.csv
# file sample_02-17-25_082607.csv had 1 rows with bad times, we will use prior time
# file sample_02-17-25_082607.csv had a bad time in first row, use the next
# Done loading log sample_02-17-25_082607.csv
# Done loading log sample_02-17-25_083507.csv
# Done loading log sample_02-18-25_064554.csv
# Done loading log sample_02-18-25_065902.csv
# Done loading log sample_02-18-25_070838.csv
# Done loading log sample_02-18-25_071824.csv
# Done loading log sample_02-18-25_073019.csv
# Done loading log sample_02-18-25_073923.csv
# Done loading log sample_02-18-25_074822.csv
# Done loading log sample_02-18-25_075716.csv
# Done loading log sample_02-18-25_080613.csv
# Done loading log sample_02-18-25_081512.csv
# Done loading log sample_02-19-25_060630.csv
# Done loading log sample_02-19-25_061633.csv
# file sample_02-19-25_062552.csv had 1 rows with bad times, we will use prior time
# Done loading log sample_02-19-25_062552.csv
# Done loading log sample_02-19-25_063504.csv
# Done loading log sample_02-19-25_064359.csv
# file sample_02-19-25_065250.csv had 1 rows with bad times, we will use prior time
# Done loading log sample_02-19-25_065250.csv
# Done loading log sample_02-19-25_070146.csv
# Done loading log sample_02-19-25_071043.csv
# Done loading log sample_02-19-25_071938.csv
# Done loading log sample_02-19-25_072834.csv
# Done loading log sample_02-19-25_073737.csv
# Done loading log sample_02-19-25_074638.csv
# Done loading log sample_02-19-25_075547.csv
# Done loading log sample_02-19-25_080443.csv
# Done loading log sample_02-19-25_081342.csv
# Done loading log sample_02-19-25_082328.csv
# Done loading log sample_02-19-25_083228.csv
# file sample_02-19-25_084136.csv had 1 rows with bad times, we will use prior time
# Done loading log sample_02-19-25_084136.csv
# Done loading log sample_02-19-25_085028.csv
# Done loading log sample_02-19-25_085919.csv
# Done loading log sample_02-19-25_090816.csv
# Done loading log sample_02-19-25_091704.csv
# Done loading log sample_02-19-25_092558.csv
# Done loading log sample_02-19-25_093502.csv
# Done loading log sample_02-19-25_094411.csv
# Done loading log sample_02-19-25_095309.csv
# Done loading log sample_02-19-25_100214.csv
# Done loading log sample_02-19-25_101116.csv
# Done loading log sample_02-19-25_102015.csv
# Done loading log sample_02-19-25_102921.csv
# Done loading log sample_02-19-25_103825.csv
# Done loading log sample_02-19-25_104731.csv
# Done loading log sample_02-19-25_105622.csv
# Done loading log sample_02-19-25_110520.csv
# Done loading log sample_02-19-25_111411.csv
# Done loading log sample_03-03-25_075739.csv
# Done loading log sample_03-03-25_080651.csv
# Done loading log sample_03-03-25_081557.csv
# Done loading log sample_03-03-25_082502.csv
# Done loading log sample_03-03-25_083411.csv
# Done loading log sample_03-03-25_084311.csv
# Done loading log sample_03-03-25_085205.csv
# Done loading log sample_03-03-25_090106.csv
# Done loading log sample_03-18-25_085631.csv
# Done loading log sample_03-18-25_090546.csv
# Done loading log sample_03-18-25_091450.csv
# Done loading log sample_03-18-25_092353.csv
# Done loading log sample_03-18-25_093252.csv
# Done loading log sample_03-18-25_095815.csv
# Done loading log sample_03-18-25_100847.csv
# Done loading log sample_03-18-25_101737.csv
# Done loading log sample_03-20-25_070559.csv
# Done loading log sample_03-20-25_071512.csv
# Done loading log sample_03-20-25_072414.csv
# Done loading log sample_03-20-25_073314.csv
# Done loading log sample_03-20-25_074224.csv
# Done loading log sample_04-01-25_064459.csv
# Done loading log sample_04-01-25_071008.csv
# Done loading log sample_04-01-25_073331.csv
# Done loading log sample_04-01-25_074251.csv
# Done loading log sample_04-01-25_075206.csv
# Done loading log sample_04-01-25_080102.csv
# Done loading log sample_04-01-25_081011.csv
# Done loading log sample_04-01-25_081913.csv
# Done loading log sample_04-01-25_082803.csv
# file sample_04-01-25_083708.csv had 1 rows with bad times, we will use prior time
# Done loading log sample_04-01-25_083708.csv
# Done loading log sample_04-01-25_084602.csv
# Done loading log sample_04-03-25_081036.csv
# Done loading log sample_04-03-25_082121.csv
# Done loading log sample_04-03-25_083034.csv
# Done loading log sample_04-03-25_084244.csv
# Done loading log sample_04-03-25_085212.csv
# Done loading log sample_04-03-25_090118.csv
# Done loading log sample_04-03-25_091457.csv
# Done loading log sample_04-08-25_074216.csv
# Done loading log sample_04-08-25_075145.csv
# Done loading log sample_04-08-25_080055.csv
# Done loading log sample_04-08-25_081127.csv
# Done loading log sample_04-08-25_082043.csv
# Done loading log sample_04-08-25_082953.csv
# Done loading log sample_04-08-25_083927.csv
# Done loading log sample_04-08-25_084824.csv
# Done loading log sample_04-08-25_085729.csv
# Done loading log sample_04-08-25_090630.csv
# Done loading log sample_04-08-25_091545.csv
# Done loading log sample_04-08-25_092441.csv
# Done loading log sample_04-14-25_075050.csv
# Done loading log sample_04-14-25_075950.csv
# Done loading log sample_04-14-25_080859.csv
# Done loading log sample_04-14-25_081825.csv
# Done loading log sample_04-14-25_082726.csv
# Done loading log sample_04-14-25_083638.csv
# Done loading log sample_04-14-25_084540.csv
# Done loading log sample_04-14-25_085431.csv
# Done loading log sample_04-14-25_100334.csv
# Done loading log sample_04-14-25_101244.csv
# Done loading log sample_04-14-25_102140.csv
# Done loading log sample_04-14-25_103030.csv
# Done loading log sample_04-14-25_103936.csv
# Done loading log sample_04-14-25_104856.csv
# Done loading log sample_04-16-25_072944.csv
# Done loading log sample_04-16-25_073851.csv
# Done loading log sample_04-16-25_074610.csv
# Done loading log sample_04-16-25_075325.csv
# Done loading log sample_04-16-25_080902.csv
# Done loading log sample_04-16-25_080914.csv
# Done loading log sample_04-16-25_081757.csv
# Done loading log sample_04-16-25_082719.csv
# Done loading log sample_04-16-25_083638.csv
# Done loading log sample_04-16-25_084556.csv
# Done loading log sample_04-16-25_085522.csv
# Done loading log sample_04-16-25_090445.csv
# Done loading log sample_04-16-25_091352.csv
# Done loading log sample_04-16-25_092320.csv
# Done loading log sample_04-16-25_093246.csv

# %% [markdown]
# # Pull Out Relevant Information

# %%
#%% Filter
df = dfraw;

#df = df[df['expname']=='20250311_SimonGhionea_autodl']
#df = df[df['unit']=='PM11'];
#df = df[df['run']=='sample_03-11-25_153808']
#df = df[df['run']=='sample_03-11-25_153400']

# %%
#%% Pull out by-cycle information

#dfbuildlist = [];
def convert_dtypes(df : pd.DataFrame):
    # try to convert strings to numerics as appropriate
    for col in df.columns:
        try:
            df[col] = pd.to_numeric(df[col]);
        except:
            pass
    
    return df

buildlist = [];
for unit,dfunits in df.groupby('unit'):
    #unit_run_counter = 0;
    for expname,dfexps in dfunits.groupby('expname'):
        for run,dfrun in dfexps.groupby('run'):
            #print('unit:{:s} exp:{:} run:{:s} shape:{:s}'.format(unit,expname,run,str(dfrun.shape)))
            
            dfrunevents = dfrun[ ~dfrun['Event'].isnull() & ~(dfrun['Event']==' ') ]
            dfrunevents = dfrunevents[['Time','Event']]
            
            status = 'nostatus';
            text = '';

            # Cycle Analysis
            evts_beg = dfrunevents[dfrunevents['Event'].str.match(r'^Cycle \d+ Started')]
            evts_end = dfrunevents[dfrunevents['Event'].str.match(r'^Cycle \d+ Stopped')]
            evts_nocyc = dfrunevents.loc[dfrunevents.index.symmetric_difference(evts_beg.index.tolist()+evts_end.index.tolist())]
            
            if( (evts_beg.shape[0]==0) & (evts_end.shape[0]==0) ):
                # was not a run
                #text+='Not A Run: {:s}'.format(str('\n'.join(dfrunevents['Event'].to_list())));
                text+='Not A Run: {:s}'.format(str(dfrunevents['Event'].to_list()));
                status = 'notrun';
                if(any(dfrunevents['Event'].str.startswith('Boot'))):
                    status = 'bootup';
                    
                    # check for boot reset reasons
                    reset_reason = dict( [tuple(s.split('=')) for s in dfrunevents['Event'].str.extract(r'POWER.RESETREAS=[^\s]*\s(.*)').dropna().iloc[0].item().split(' ')] );
                    # all reasons 0, I think that means power-on (turned on from switch) based on my reading of Nordic datasheet
                    if(all([v=='0' for k,v in reset_reason.items()])):
                        status+=',POR';
                
                dfrunevents['expname'] = expname;
                dfrunevents['unit'] = unit;
                dfrunevents['run'] = run;
                dfrunevents['status'] = status;
                dfrunevents['text'] = text;
                dfrunevents['Cycle'] = 0;
                dfrunevents = dfrunevents.rename(columns={'Time':'TimeBeg'})
                #buildlist.append(dfrunevents);
                buildlist.append( dfrunevents.drop(columns=['Event']).iloc[[0]] );
            
            elif( evts_beg.shape[0]==evts_end.shape[0]):
                #print('here5')
                # all Start and Stopped are matched
                ncycles = evts_beg.shape[0];
                cyc_num_beg = evts_beg['Event'].str.extract(r'Cycle (\d+) ',expand=False).astype(np.uint8);
                cyc_num_beg.name='Cycle'
                cyc_num_end = evts_end['Event'].str.extract(r'Cycle (\d+) ',expand=False).astype(np.uint8);
                cyc_num_end.name='Cycle'
                earlyterm = any(evts_end['Event'].str.match(r'.*early\.'));
                earlyterm = earlyterm | any(evts_nocyc['Event'].str.match(r'.*error.*'));
                earlyterm = earlyterm | any(evts_nocyc['Event'].str.match(r'.*stall*'));
                if(cyc_num_beg.shape[0]>0):
                    fn_lmbda_split_keyvalue_strings = lambda x: dict(tuple([tuple(z.split('=')) for z in x]));

                    #cyc_data_beg = evts_beg['Event'].str.extract(r'Cycle \d.*\.+( .*)',expand=False).str.split(' ').apply(lambda x: x[1:]).apply(lambda x: dict(tuple([tuple(z.split('=')) for z in x]))).apply(pd.Series)
                    #cyc_data_end = evts_end['Event'].str.extract(r'Cycle \d.*\.+( .*)',expand=False).str.split(' ').apply(lambda x: x[1:]).apply(lambda x: dict(tuple([tuple(z.split('=')) for z in x]))).apply(pd.Series)
                    cyc_data_beg = evts_beg['Event'].str.extract(r'Cycle \d.*\.+( .*)',expand=False).str.split(' ');
                    if(not all(cyc_data_beg.isna())):
                        # there are fields after "Cycle N started." messages
                        cyc_data_beg = cyc_data_beg.apply(lambda x: x[1:]).apply(fn_lmbda_split_keyvalue_strings).apply(pd.Series)
                        cyc_data_beg = convert_dtypes(cyc_data_beg);

                        evts_beg = pd.concat((evts_beg,cyc_num_beg,cyc_data_beg),axis='columns')
                        #print('here1');
                    else:
                        evts_beg = pd.concat((evts_beg,cyc_num_beg),axis='columns');
                        #print('here2');
                    evts_beg = evts_beg.rename(columns={'Time':'TimeBeg'})


                    cyc_data_end = evts_end['Event'].str.extract(r'Cycle \d.*\.+( .*)',expand=False).str.split(' ');
                    if(not all(cyc_data_end.isna())):
                        # there are fields after "Cycle N started." messages
                        cyc_data_end = cyc_data_end.apply(lambda x: x[1:]).apply(fn_lmbda_split_keyvalue_strings).apply(pd.Series)
                        cyc_data_end = convert_dtypes(cyc_data_end);

                        evts_end = pd.concat((evts_end,cyc_num_end,cyc_data_end),axis='columns')
                        #print('here3')
                    else:
                        evts_end = pd.concat((evts_end,cyc_num_end),axis='columns');
                        #print('here4');
                    evts_end = evts_end.rename(columns={'Time':'TimeEnd'})

                    # Combine Beginning and Ending of cycle information into a single cycle row
                    cyc_data = pd.merge(evts_beg,evts_end,on='Cycle',suffixes=('Beg','End')).set_index('Cycle',drop=True);

                    # calculate cycle information
                    cyc_data['CCycleRTCSeconds'] = (cyc_data['TimeEnd']-cyc_data['TimeBeg']).apply(lambda x: x.total_seconds());
                    #cyc_data.loc[0,['EventEnd']] = 'norm'
                else:
                    print('\tOTHER')

                
                if(earlyterm):                   
                    # print('\tEarly abort in cycle {:d} @ {:.0f} s @ total runtime {:.0f} s:'.format(
                    #     cyc_data.index[-1],
                    #     cyc_data['CalcCycleRTCSeconds'].iloc[-1].item(),
                    #     cyc_data['CalcCycleRTCSeconds'].sum().item()
                    #     )
                    # )
                    text += 'Early abort in cycle {:d} @ {:.0f} s @ total runtime {:.0f} s:\n'.format(
                        cyc_data.index[-1],
                        cyc_data['CCycleRTCSeconds'].iloc[-1].item(),
                        cyc_data['CCycleRTCSeconds'].sum().item()
                    );
                    #print('\t',str(evts_nocyc['Event'].to_list()))
                    #text += '{:s}'.format('\n'.join(evts_nocyc['Event'].to_list()));
                    text += '{:s}'.format(str(evts_nocyc['Event'].to_list()));
                    normal_interruptions = [
                        'HALL sensor interrupted',
                        'Optical sensor interrupted',
                        'ButtonCycle cancled via button click',
                    ]
                    if(any(pd.concat([evts_nocyc['Event'].str.contains(s) for s in normal_interruptions]))):
                        status = 'run_ended_early_user';
                    else:
                        status = 'run_ended_early_other';
                    # if(evts_nocyc['Event'].str.contains('Optical sensor interrupted')|evts_nocyc['Event'].str.contains('Hall sensor interrupted')):
                    #     status = 'run_ended_early';
                else:
                    # print('\tCompletedRun @ total runtime {:.0f} s'.format(
                    #     cyc_data['CalcCycleRTCSeconds'].sum().item()
                    # ))
                    text += 'CompletedRun @ total runtime {:.0f}s:'.format(
                        cyc_data['CCycleRTCSeconds'].sum().item()
                    )
                    #text += '{:s}'.format('\n'.join(evts_nocyc['Event'].to_list()));
                    text += '{:s}'.format(str(evts_nocyc['Event'].to_list()));
                    status = 'run_success';
                
                try:
                    if(not earlyterm):
                        if( not all(cyc_data_beg['runtime_s']==cyc_data_end['expected_sec']) ):
                            #print('\tMismatched runtimes');
                            text += '\n\tMismatched runtimes';
                            status = 'run_mismatched_runtimes';
                    else:
                        if( not all(cyc_data_beg['runtime_s'][0:-1]==cyc_data_end['expected_sec'][0:-1]) ):
                            #print('\tMismatched runtimes (early)');
                            text += '\n\tMismatched runtimes (early)';
                            status = 'run_mismatched_runtimes_early';
                except:
                    pass;
                
                # SUMMARIZE PER RUN
                if(not earlyterm):
                    pass;
                    # for (k1,v1),(k2,v2) in zip(evts_beg.iterrows(),evts_end.iterrows()):
                    #     #print( 'Cycle{:d} idx{:d} to idx{:d}'.format(v1['Cycle'],k1,k2) );
                        
                    #     # subset this cycle in the run
                    #     dfruncyc = dfrun.loc[k1:k2]

                    #     # last third
                    #     dfruncyclst3rd = dfruncyc.loc[k2-((k2-k1)//3):]

                    #     # calculate some summaries
                    #     #cyc_data.loc[v1['Cycle'],'C'] = cyc_data['CCycleRTCSeconds'].sum().item()
                    #     cyc_data.loc[v1['Cycle'],'CL3MedAmpTemp'] = dfruncyclst3rd['AmpTemp'].median()
                    #     cyc_data.loc[v1['Cycle'],'CL3MedValveTemp'] = dfruncyclst3rd['ValveTemp'].median()
                    #     cyc_data.loc[v1['Cycle'],'CL3MaxAmpPWM'] = dfruncyclst3rd['AmpPWM'].max()
                    #     cyc_data.loc[v1['Cycle'],'CL3MaxValvePWM'] = dfruncyclst3rd['ValvePWM'].max()
                    #     cyc_data.loc[v1['Cycle'],'CMaxAmpTemp'] = dfruncyc['AmpTemp'].max()
                    #     cyc_data.loc[v1['Cycle'],'CMaxValveTemp'] = dfruncyc['ValveTemp'].max()

                    #     pass
                for (k1,v1),(k2,v2) in zip(evts_beg.iterrows(),evts_end.iterrows()):
                    #print( 'Cycle{:d} idx{:d} to idx{:d}'.format(v1['Cycle'],k1,k2) );
                    
                    # subset this cycle in the run
                    dfruncyc = dfrun.loc[k1:k2]

                    # last third
                    dfruncyclst3rd = dfruncyc.loc[k2-((k2-k1)//3):]

                    # calculate some summaries
                    #cyc_data.loc[v1['Cycle'],'C'] = cyc_data['CCycleRTCSeconds'].sum().item()
                    #cyc_data.loc[v1['Cycle'],'C'] = cyc_data['CCycleRTCSeconds'].sum().item()
                    # is power module?
                    if 'AmpTemp' in dfruncyclst3rd.columns:
                        cyc_data.loc[v1['Cycle'],'CL3MedAmpTemp'] = dfruncyclst3rd['AmpTemp'].median()
                        cyc_data.loc[v1['Cycle'],'CL3MedValveTemp'] = dfruncyclst3rd['ValveTemp'].median()
                        cyc_data.loc[v1['Cycle'],'CL3MaxAmpPWM'] = dfruncyclst3rd['AmpPWM'].max()
                        cyc_data.loc[v1['Cycle'],'CL3MaxValvePWM'] = dfruncyclst3rd['ValvePWM'].max()
                        cyc_data.loc[v1['Cycle'],'CMaxAmpTemp'] = dfruncyc['AmpTemp'].max()
                        cyc_data.loc[v1['Cycle'],'CMaxValveTemp'] = dfruncyc['ValveTemp'].max()

                    pass
                #cyc_data['CRTCRuntime'] = (dfrun['Time'].iloc[[0,-1]]).diff().apply(lambda x: x.total_seconds()).iloc[-1].item();
                cyc_data['CRTCRuntime'] = ( cyc_data.iloc[-1]['TimeEnd'] - cyc_data.iloc[0]['TimeBeg'] ).total_seconds();

                cyc_data['expname'] = expname;
                cyc_data['unit'] = unit;
                cyc_data['run'] = run;
                cyc_data['status'] = status;
                cyc_data['text'] = text;
                buildlist.append(cyc_data.reset_index());
            else:
                print('Nonsensical')
                text += 'Run cycles non-sensical, nbegun={:d} nended={:d}'.format(evts_beg.shape[0],evts_end.shape[0]);
                status = 'nonsensical_cycles';

                dfrunevents['expname'] = expname;
                dfrunevents['unit'] = unit;
                dfrunevents['run'] = run;
                dfrunevents['status'] = status;
                dfrunevents['text'] = text;
                dfrunevents['Cycle'] = 0;
                dfrunevents.rename(columns={'Time':'TimeBeg'});
                buildlist.append(dfrunevents);

            if(status == 'notrun'):
                print('unit:{:s} exp:{:} run:{:s} shape:{:s} status:{:s}'.format(unit,expname,run,str(dfrun.shape),status))
                print(text)
            #break;


#dflifetest = pd.concat(dfbuildlist)
dfbuilt = pd.concat(buildlist,ignore_index=True)
dfbuilt['Cycle'] = dfbuilt['Cycle'].astype(np.uint8)
dfbuilt = dfbuilt.set_index(['unit','expname','run','Cycle'])
#dfbuilt = pd.concat(buildlist).reset_index()

#%% Show run summary
# Out:
# Nonsensical
# unit:SP46 exp:20250410_CoDxQuantigen_failunit run:sample_02-05-25_113645 shape:(1, 14) status:notrun
# Not A Run: ['Sample preperation unit powered on. Starting battery voltage: 4.16']
# Nonsensical
# Nonsensical
# unit:SP46 exp:20250410_CoDxQuantigen_failunit run:sample_02-05-25_114342 shape:(1, 14) status:notrun
# Not A Run: ['Sample preperation unit powered on. Starting battery voltage: 4.17']
# unit:SP46 exp:20250410_CoDxQuantigen_failunit run:sample_02-05-25_114346 shape:(1, 14) status:notrun
# Not A Run: ['Sample preperation unit powered on. Starting battery voltage: 4.17']
# unit:SP53 exp:20250410_CoDxQuantigen_failunit run:sample_01-01-00_000204 shape:(1, 14) status:notrun
# Not A Run: ['Sample preperation unit powered on. Starting battery voltage: 4.11']
# unit:SP53 exp:20250410_CoDxQuantigen_failunit run:sample_01-01-00_001449 shape:(1, 14) status:notrun
# Not A Run: ['Sample preperation unit powered on. Starting battery voltage: 4.10']
# unit:SP53 exp:20250410_CoDxQuantigen_failunit run:sample_01-19-00_094841 shape:(1, 14) status:notrun
# Not A Run: ['Sample preperation unit powered on. Starting battery voltage: 4.17']
# unit:SP53 exp:20250410_CoDxQuantigen_failunit run:sample_01-19-00_094858 shape:(1, 14) status:notrun
# Not A Run: ['Sample preperation unit powered on. Starting battery voltage: 4.16']
# Nonsensical
# unit:SP53 exp:20250410_CoDxQuantigen_failunit run:sample_01-30-25_160054 shape:(1, 14) status:notrun
# Not A Run: ['Sample preperation unit powered on. Starting battery voltage: 4.18']
# unit:SP53 exp:20250410_CoDxQuantigen_failunit run:sample_01-30-25_160209 shape:(1, 14) status:notrun
# Not A Run: ['Sample preperation unit powered on. Starting battery voltage: 4.18']
# Nonsensical
# Nonsensical
# Nonsensical
# unit:SP53 exp:20250410_CoDxQuantigen_failunit run:sample_04-01-25_064459 shape:(1, 14) status:notrun
# Not A Run: ['Sample preperation unit powered on. Starting battery voltage: 4.18']
# unit:SP53 exp:20250410_CoDxQuantigen_failunit run:sample_04-16-25_080902 shape:(1, 14) status:notrun
# Not A Run: ['Sample preperation unit powered on. Starting battery voltage: 4.20']

# %%
#%% Pull out only whole-run-summaries
#%% Show run summary
#for (unit,expname,run),dfgrp in dfbuilt.xs(1,level='Cycle').groupby(['unit','expname','run']):
runbuild = [];
for (unit,expname,run),dfgrp in dfbuilt.groupby(['unit','expname','run']):
    dfcyclesorted = dfgrp.sort_values('Cycle');
    dffirst = dfcyclesorted.reset_index().iloc[0];
    dflast = dfcyclesorted.reset_index().iloc[-1];
    #print(unit,expname,run,dffirst.shape)
    #print(dffirst['text'])

    calc_cols_from_cycles_to_sum = ['I2CERRCOUNT'];
    calc_cols_from_cycles_to_max = ['tick_delta_sec','rtc_delta_sec'];
    calc_cols_from_cycles_to_first = ['CRTCRuntime'];

    cols_to_always_include = ['status','text']

    runseriesitem = dfgrp.reset_index(level='Cycle').iloc[0][cols_to_always_include+calc_cols_from_cycles_to_first];
    runseriesitem['TimeBeg'] = dffirst['TimeBeg'];
    runseriesitem['TimeEnd'] = dflast['TimeEnd'];
    
    # items to max across cycles
    for col in calc_cols_from_cycles_to_max:
        if(col in dfgrp.columns):
            runseriesitem['cycmax_'+col] = dfgrp[col].max();
    
    # items to sum across cycles
    for col in calc_cols_from_cycles_to_sum:
        if(col in dfgrp.columns):
            runseriesitem['cycsum_'+col] = dfgrp[col].sum();
    
    # get other events
    if(runseriesitem['status']=='run_success'):
        dfrunevents = df[df['Event']!=' '].query("unit==@unit and expname==@expname and run==@run")
        
        fn_lmbda_split_keyvalue_strings = lambda x: dict(tuple([tuple(z.split('=')) for z in x]));
        
        # get parameters after "Run complete"
        if( dfrunevents['Event'].str.startswith('Run complete').dropna().any() ):
            inlineparams = dfrunevents[dfrunevents['Event'].str.startswith('Run complete')]['Event'].str.extract(r'Run complete. (.*)',expand=False);
            if(inlineparams.shape[0]>0):
                run_complete_params = fn_lmbda_split_keyvalue_strings( inlineparams.iloc[0].split(' ') )

                for k,v in run_complete_params.items():
                    runseriesitem['run_'+k] = v;

    runbuild.append( runseriesitem );

    # if(dfgrp.shape[0]==4):
    #     break;
dfruns = pd.DataFrame(runbuild);
dfruns.index.set_names(["unit","expname","run"],inplace=True)

# %% [markdown]
# # DataExplorer Panel

# %%
#dffull = dfbuilt.reset_index().copy();
dffull = dfruns.reset_index().copy();
dffullorig = dffull.copy(); #<-- store a copy so we can come back to this
dfsel = pd.DataFrame();

# %%
dffull = dffull[~dffull['TimeBeg'].isna()]

# %%
# %% Helpers
def filtered_dataframe(param_values,param_columns):
    
    selection_dict = pd.Series(param_values)[list(param_columns.keys())].to_dict();
    print('selection_dict',selection_dict);

    # this line will filter the dataframe using param_values and param_columns
    #dffiltered = dffull.isin(pd.Series(obj.param.values())[param_columns.keys()].to_dict())[param_columns].all(axis=1);
    #dffiltered = dffull[dffull.isin(pd.Series(param_values)[param_columns.keys()].to_dict())[param_columns].all(axis=1)]

    dffiltered = dffull[dffull.isin(selection_dict)[param_columns.keys()].all(axis=1)]
    
    return dffiltered;

# %%
from panel.viewable import Viewer
import param

data_url = "https://assets.holoviz.org/panel/tutorials/turbines.csv.gz"
#turbines = pn.cache(pd.read_csv)(data_url)

c_def_cols = ["unit","expname","run","TimeBeg","status","text"];
c_filters = {
    "expname":param.ListSelector,
    "unit":param.ListSelector,
    "status":param.ListSelector,
    "TimeBeg":param.DateRange
};
# c_def_cols = ["unit","expname","run","Cycle","TimeBeg","status","text"];
# c_filters = {
#     "expname":param.ListSelector,
#     "unit":param.ListSelector,
#     "status":param.ListSelector,
#     "Cycle":param.ListSelector,
#     "TimeBeg":param.DateRange
# };

def update_or_add_parameters(obj,param_columns):
    for col,paramobj in param_columns.items():
        items = dffull[col].unique().tolist();
        
        if(paramobj == param.ListSelector):
            if col not in obj.param:
                # add parameter
                newParam = paramobj(default=sorted(items),objects=sorted(items));
                print('Adding param',col,'dffull.shape',dffull.shape)
                obj.param.add_parameter(col,newParam);
            else:
                # update parameter
                print('Updating param',col,'dffull.shape',dffull.shape)
                # reset available options
                obj.param[col].objects = items;
                # reset selections (to all)
                setattr(obj,col,items);
        elif(paramobj == param.DateRange):
            print('DateRange')
            if col not in obj.param:
                # add parameter
                beg = sorted(dffull['TimeBeg'].unique())[0];
                end = sorted(dffull['TimeBeg'].unique(),reverse=True)[0];
                newParam = paramobj(default=(beg,end),bounds=(beg,end));
                print('Adding param',col,'dffull.shape',dffull.shape)
                obj.param.add_parameter(col,newParam);

class DataExplorer(Viewer):
    data = param.DataFrame(doc="Stores a DataFrame to explore")

    columns = param.ListSelector(
        #default=["p_name", "t_state", "t_county", "p_year", "t_manu", "p_cap"]
        default=c_def_cols,
    )

    filtered_table_data = param.DataFrame(doc="Stores the filtered DataFrame For Table Display")
    filtered_timeline_data = param.DataFrame(doc="Stores the filtered DataFrame For Timeline Display")
    import plotly.graph_objects as go
    timeline_panel = pn.pane.Plotly(
                None,
                sizing_mode='stretch_both', width_policy='max'
            );
    
    tabulator_widget = None;

    def __init__(self, **params):
        super().__init__(**params)
        
        # set parameter for columns to those from dataframe
        self.param.columns.objects = self.data.columns.to_list()

        # dynamically add parameters
        update_or_add_parameters(self,c_filters);

    @param.depends("data", "columns", watch=True, on_init=True)
    def _update_filtered_data(self):
        df = self.data
        # self.filtered_data=df[df.p_year.between(*self.year) & df.p_cap.between(*self.capacity)][
        #     self.columns
        # ]

        #minimum_timeline_columns = ['unit','expname','run','status','TimeBeg','TimeEnd']
        #cols_timeline = list(set(self.columns).union(set(minimum_timeline_columns)));
        cols_table = self.columns;
    
        # TABLE
        # after filtering
        dftable = df[ cols_table ];
    
        # some formatting
        dftable['runraw'] = dftable['run'];
        def mkrunlink(x):
            if((x['status'] == 'run_success') or (x['status'].find('run_ended_early')>=0)):
                #return '<a href="file:///c:\\TEMP\\NAATOS_PM_RUN_runtime_{:s}_{:s}_{:s}.html" target="_blank">{:s}</a>'.format( x['expname'],x['unit'],x['run'],x['run'] );
                return '<a href="rundetail?expname={:s}&unit={:s}&run={:s}" target="_blank">{:s}</a>'.format( x['expname'],x['unit'],x['run'],x['run'] );
            else:
                return x['run'];
            #return 'test';
        ret = dftable.apply( lambda x: mkrunlink(x) ,axis=1);
        dftable['run'] = ret.tolist();

        self.filtered_table_data = dftable;
    

        # TABLE
        # after filtering
        dftimeline = df;
    
        self.filtered_timeline_data = dftimeline;


    @param.depends('filtered_table_data')
    def number_of_rows(self):
        return f"Rows: {len(self.filtered_table_data)}"
    
    def _timelinePlotlyWidget(self):
        print('_timelinePlotlyWidget called');
        #print(self.filtered_timeline_data);
        try:
            fig = logplotter.mkplot_runs_timeline(self.filtered_timeline_data);
            fig.layout.autosize = True;
            self.timeline_panel.object = fig;
        except Exception as e:
            print(e);
            return 'error occurred making timeline'
        return self.timeline_panel;

    @pn.depends(timeline_panel.param.click_data, watch=True)
    def _timeline_click_handling(click_data):
        print("click datatype:{:s} data:{:s}", type(click_data), str(click_data));
        if( type(click_data) == dict ):
            click_expname = click_data['points'][0]['customdata'][0];
            click_run = click_data['points'][0]['customdata'][1];
            click_unit = click_data['points'][0]['y'];
            # # click_expname = click_data.points[0]['customdata'][0];
            # # click_run = click_data.points[0]['customdata'][0];
            # # click_unit = click_data.points[0]['y'];
            print('You clicked on exp:{:s} unit:{:s} run:{:s}'.format(click_expname,click_unit,click_run))

    def _tabulatorWidget(self):
        print('_tabulatorWidget called');

        header_filters = {
            'text': {'type': 'input', 'func': 'like', 'placeholder': 'Search text'},
        }
        tabulator_editors = {
            'unit': {'type': 'list', 'valuesLookup': True},
            'status': {'type': 'list', 'valuesLookup': True},
            'text': {'type': 'input', 'func': 'like', 'placeholder': 'Search text'},
        }
        pn_summarytable = pn.widgets.Tabulator(
            value=self.param.filtered_table_data,

            pagination='local', page_size=30,
            #pagination='local',page_size=1000,

            #hierarchical=True,
            #groupby=['expname','unit'],
            #theme='midnight',
            #aggregators={"origin": "mean", "yr": "mean"},
            
            show_index=False,
            formatters = {
                'run': dict(type='html'),
                'text': dict(type='textarea'),
            },

            #header_filters=header_filters,
            editors=tabulator_editors,header_filters=True,

            configuration=dict(
                paginationCounter="rows"
            ),
            
            sizing_mode='stretch_both',
        );

        # apply dataframe styling to the tabulator widget
        # https://discourse.holoviz.org/t/dynamic-update-of-tabulator-style/2741
        # STYLING
        def style_statustext(val):
            """
            Takes a scalar and returns a string with
            the css property
            """
            if(val=='run_success'):
                return "background-color: lightgreen";
            elif(val=='run_ended_early_user'):
                return "background-color: lightyellow";
            elif(val=='notrun'):
                return '';
            elif(val.find('boot')>=0):
                return "background-color: powderblue";
            else:
                return "background-color: orchid";
        mydf_styled = pn_summarytable.style.map(style_statustext,subset=pd.IndexSlice[:, ['status']]);


        return pn_summarytable;

    def __panel__(self):
        print('__panel__() method called')
        c_display = set(obj.param.values().keys())-set(('columns','data','filtered_data','filtered_table_data','filtered_timeline_data','name'));
        
        self.tabulator_widget = self._tabulatorWidget();

        return pn.Column(
            pn.Row(
                pn.Column(
                    pn.widgets.MultiChoice.from_param(self.param.columns, width=400),
                ),
                #pn.Column(self.param.year, self.param.capacity),
                *[obj.param[x] for x in c_display]
            ),
            self.number_of_rows,
            
            #pn.widgets.Tabulator(self.param.filtered_data, page_size=10, pagination="remote"),
            
            pn.Tabs(
                ('Timeline',self._timelinePlotlyWidget()),
                ('Table',self.tabulator_widget),
                dynamic=True
            )
        )
#s = DataExplorer(data=turbines).servable()
obj = DataExplorer(data=dffull)
#s = obj.servable();
#obj.servable();
# Out:
# Adding param expname dffull.shape (326, 8)
# Adding param unit dffull.shape (326, 8)
# Adding param status dffull.shape (326, 8)
# DateRange
# Adding param TimeBeg dffull.shape (326, 8)
# C:\Users\SimonGhionea\AppData\Local\Temp\ipykernel_60192\2711795649.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dftable['runraw'] = dftable['run'];
# C:\Users\SimonGhionea\AppData\Local\Temp\ipykernel_60192\2711795649.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dftable['run'] = ret.tolist();

# %% [markdown]
# # Plotting Panel

# %%
def_expname,def_unit,def_run = list( dffull[dffull['status']=='run_success'].groupby(['expname','unit','run']).groups.keys() )[0];
class Plotter1App(Viewer):
    dffull = param.DataFrame(doc="Stores the master dataframe")
    dfbuilt = param.DataFrame(doc="Stores the processed cycle run")

    expname = param.String();
    unit = param.String();
    run = param.String();

    def __init__(self,**params):
        # get first info and set as default property
        print('INIT',def_expname,def_unit,def_run);
        self.param.expname.default = def_expname;
        self.param.unit.default = def_unit;
        self.param.run.default = def_run;
    
        super().__init__(**params);
    
        #pn.state.location.sync(self,['unit'])
    
    def __panel__(self):
        # return pn.Column(
        #     pn.Row(
        #         pn.Column(
        #             pn.widgets.MultiChoice.from_param(self.param.columns, width=400),
        #         ),
        #         #pn.Column(self.param.year, self.param.capacity),
        #         pn.
        #     ),
            
        #     #pn.widgets.Tabulator(self.param.filtered_data, page_size=10, pagination="remote"),
        #     self._tabulatorWidget()

        # pn.Column(

        # )
        # print('2 __panel__');
        # print('2 __panel__',pn.state.location);
        # print(dir(pn.state.location))
        # print(pn.state.session_args);
        
        
        # print(pn.state.location.query_params);
        
        # # # set from query params if they were passed-in
        # # for k,v in pn.state.location.query_params.items():
        # #     if(k in self.param):
        # #         #setattr(self,k,v);
        # #         #self.param.set_param(k,v);
        # #         pass;

        run=self.run;
        unit=self.unit;
        expname=self.expname;
        print('PANEL',expname,unit,run);

        # #pn.state.location.sync(self,['unit'])
        dfplot = self.dffull.query('run==@run and expname==@expname and unit==@unit')
        plotly_fig = logplotter.mkplot_devicerun_detail(dfplot,self.dfbuilt);
        plotly_fig.layout.autosize = True;
        pn_content = pn.pane.Plotly(
            plotly_fig
            ,sizing_mode='stretch_both', width_policy='max'
        )

        # get logfile info
        logfile,configfiles = logreader.getFilesByExpUnitRun(rootpath,experiment=expname,unit=unit,run=run);

        return pn.Tabs(
            # pn.Row(
            #     self.param.expname,self.param.unit,self.param.run
            # ),
            #'PLOT GOES HERE '+str(pn.state.location.query_params),
            #'PLOT GOES HERE '+unit+' '+expname+' '+run,
            ('Run Detail Plot',pn_content),
            ('Logfile',pn.pane.Str('Dumping {:s}\n\n'.format(str(logfile[0]))+logfile[1])),
        );
#obj2 = Plotter1App(dffull = dfraw, dfbuilt = dfbuilt);
#obj2.servable()

# %% [markdown]
# # Panel Multi-Page Setup 2

# %%
def session_key_func(request):
    key = request.arguments.get('expname', [def_expname.encode()])[0]+'_'+request.arguments.get('unit', [def_unit.encode()])[0]+'_'+request.arguments.get('run', [def_run.encode()])[0];
    print('session_key_func',key);
    return key;

#pn.extension(template='material', session_key_func=session_key_func)
pn.extension(session_key_func=session_key_func)

obj = DataExplorer(data=dffull)
obj2 = Plotter1App(dffull = dfraw, dfbuilt = dfbuilt);

def page1():
    #return obj.servable(location=True)
    return obj;

def page_rundetail():
    #pn.state.location.sync(obj2,['unit']);
    pn.state.location.sync(obj2, ['expname','unit','run']);
    #return obj2.servable()
    return obj2;

ROUTES = {
    "": page1,
    "rundetail": page_rundetail
}
# # if pn.state.location:
# #     pn.state.location.sync(obj2)
try:
    serve.stop();
except Exception as e:
    print(e)
serve = pn.serve(ROUTES, port=5006,location=True,verbose=True,admin=True);
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='61de0caa-e618-4b53-a899-58f25b9d5d06'>
#   <div id="b4d9874c-0c39-4a2f-8687-e3e87646933d" data-root-id="61de0caa-e618-4b53-a899-58f25b9d5d06" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"dcad6bf4-d4de-4558-ac9a-ad6875ea5151":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"61de0caa-e618-4b53-a899-58f25b9d5d06"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"03d1cc6c-9778-4a55-bf6e-89b8461bbc65","attributes":{"plot_id":"61de0caa-e618-4b53-a899-58f25b9d5d06","comm_id":"3539bc0c375a4a4a83b776481b7fcc24","client_comm_id":"509b1b4979824d618a80ca4b61def5ae"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"dcad6bf4-d4de-4558-ac9a-ad6875ea5151","roots":{"61de0caa-e618-4b53-a899-58f25b9d5d06":"b4d9874c-0c39-4a2f-8687-e3e87646933d"},"root_ids":["61de0caa-e618-4b53-a899-58f25b9d5d06"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# C:\Users\SimonGhionea\AppData\Local\Temp\ipykernel_60192\2711795649.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dftable['runraw'] = dftable['run'];
# C:\Users\SimonGhionea\AppData\Local\Temp\ipykernel_60192\2711795649.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dftable['run'] = ret.tolist();
# Updating param expname dffull.shape (326, 8)
# Updating param unit dffull.shape (326, 8)
# Updating param status dffull.shape (326, 8)
# DateRange
# INIT 20250410_CoDxQuantigen_failunit SP46 sample_02-06-25_082044
# name 'serve' is not defined
# Launching server at http://localhost:5006
# __panel__() method called
# _tabulatorWidget called
# _timelinePlotlyWidget called
# WARNING:root:Dropping a patch because it contains a previously known reference (id='1e7701c8-3cf9-4fdd-b77f-44727fa5d172'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# PANEL 20250410_CoDxQuantigen_failunit SP53 sample_04-16-25_073851
# ['HeaterTemp', 'BatteryT']
# ['HeaterPWM', 'MotorPWM', 'Battery']
# ['MotorSpeed']
# ['BatteryV']
# c:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisnaatos\naatos_module_tools\logplotter.py:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# poost
# PANEL 20250410_CoDxQuantigen_failunit SP53 sample_04-16-25_073851
# ['HeaterTemp', 'BatteryT']
# ['HeaterPWM', 'MotorPWM', 'Battery']
# ['MotorSpeed']
# ['BatteryV']
# c:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisnaatos\naatos_module_tools\logplotter.py:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# WARNING:bokeh.server.views.ws:Failed sending message as connection was closed
# WARNING:bokeh.server.views.ws:Failed sending message as connection was closed
# WARNING:bokeh.server.views.ws:Failed sending message as connection was closed
# WARNING:bokeh.server.views.ws:Failed sending message as connection was closed
# WARNING:bokeh.server.views.ws:Failed sending message as connection was closed
# poost
# PANEL 20250410_CoDxQuantigen_failunit SP53 sample_04-16-25_075325
# ['HeaterTemp', 'BatteryT']
# ['HeaterPWM', 'MotorPWM', 'Battery']
# ['MotorSpeed']
# ['BatteryV']
# poost
# c:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisnaatos\naatos_module_tools\logplotter.py:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# PANEL 20250410_CoDxQuantigen_failunit SP53 sample_04-16-25_074610
# ['HeaterTemp', 'BatteryT']
# ['HeaterPWM', 'MotorPWM', 'Battery']
# ['MotorSpeed']
# ['BatteryV']
# poost
# c:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisnaatos\naatos_module_tools\logplotter.py:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ERROR:tornado.application:Uncaught exception GET /ws (::1)
# HTTPServerRequest(protocol='http', host='localhost:5006', method='GET', uri='/ws', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "c:\Users\SimonGhionea\miniconda3\envs\naatos_sg\Lib\site-packages\tornado\websocket.py", line 938, in _accept_connection
#     open_result = handler.open(*handler.open_args, **handler.open_kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\SimonGhionea\miniconda3\envs\naatos_sg\Lib\site-packages\tornado\web.py", line 3301, in wrapper
#     return method(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\SimonGhionea\miniconda3\envs\naatos_sg\Lib\site-packages\bokeh\server\views\ws.py", line 149, in open
#     raise ProtocolError("Token is expired. Configure the app with a larger value for --session-token-expiration if necessary")
# bokeh.protocol.exceptions.ProtocolError: Token is expired. Configure the app with a larger value for --session-token-expiration if necessary
# ERROR:tornado.application:Uncaught exception GET /rundetail/ws?expname=20250410_CoDxQuantigen_failunit&unit=SP53&run=sample_04-16-25_074610 (::1)
# HTTPServerRequest(protocol='http', host='localhost:5006', method='GET', uri='/rundetail/ws?expname=20250410_CoDxQuantigen_failunit&unit=SP53&run=sample_04-16-25_074610', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "c:\Users\SimonGhionea\miniconda3\envs\naatos_sg\Lib\site-packages\tornado\websocket.py", line 938, in _accept_connection
#     open_result = handler.open(*handler.open_args, **handler.open_kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\SimonGhionea\miniconda3\envs\naatos_sg\Lib\site-packages\tornado\web.py", line 3301, in wrapper
#     return method(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\SimonGhionea\miniconda3\envs\naatos_sg\Lib\site-packages\bokeh\server\views\ws.py", line 149, in open
#     raise ProtocolError("Token is expired. Configure the app with a larger value for --session-token-expiration if necessary")
# bokeh.protocol.exceptions.ProtocolError: Token is expired. Configure the app with a larger value for --session-token-expiration if necessary
# ERROR:tornado.application:Uncaught exception GET /ws (::1)
# HTTPServerRequest(protocol='http', host='localhost:5006', method='GET', uri='/ws', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "c:\Users\SimonGhionea\miniconda3\envs\naatos_sg\Lib\site-packages\tornado\websocket.py", line 938, in _accept_connection
#     open_result = handler.open(*handler.open_args, **handler.open_kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\SimonGhionea\miniconda3\envs\naatos_sg\Lib\site-packages\tornado\web.py", line 3301, in wrapper
#     return method(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\SimonGhionea\miniconda3\envs\naatos_sg\Lib\site-packages\bokeh\server\views\ws.py", line 149, in open
#     raise ProtocolError("Token is expired. Configure the app with a larger value for --session-token-expiration if necessary")
# bokeh.protocol.exceptions.ProtocolError: Token is expired. Configure the app with a larger value for --session-token-expiration if necessary

# %%
expname='20250404_PM_fromDX'; unit='Unit 2'; run='sample_04-01-25_134548';
#obj.filtered_table_data.query('expname==@expname and unit==@unit and run==@run')
dftmp = obj.filtered_table_data.query('expname==@expname and unit==@unit and runraw==@run')
print(dftmp[['expname','unit','runraw']])
#obj.

# %%
dir(obj)

# %%
dir(obj.tabulator_widget)

# %%
obj.tabulator_widget.selection=[32]

# %%
tmp = pn.widgets.Tabulator();
tmp.table.

# %%
serve.stop()

# %%
dir(serve)

# %%
dir(serve.get_sessions()[0])

# %%
expname = "20250410_CoDxQuantigen_failunit"
unit = "SP46"
run = "sample_02-19-25_101108"
dfplot = obj2.dffull.query('run==@run and expname==@expname and unit==@unit')
# #mkplot(dfplot);
plotly_fig = logplotter.mkplot_devicerun_detail(dfplot,dfbuilt);
plotly_fig.show(render='browser')

#logfile,configfiles = logreader.getFilesByExpUnitRun(rootpath,experiment=expname,unit=unit,run=run);

# %%
a = dfplot['Event'].str.startswith(' ').convert_dtypes().fillna(False)

# %%
a.info()

# %%
dffull.query('run==@run and expname==@expname and unit==@unit')

# %%
logplotter.mkplot_devicerun_detail(dfplot,dfbuilt);

# %% [markdown]
# # Manual Plot - Look at RTC time error to tick time error

# %%
dftmp = dffull[dffull['status']=='run_success']
print(dftmp.columns)
dftmp = dftmp[['expname','unit','run','run_tick_delta_sec']]
dftmp['run_tick_delta_sec'] = dftmp['run_tick_delta_sec'].astype(float)
fig = px.strip(dftmp,x='unit',y="run_tick_delta_sec");
fig.update_layout(title='Run Timing Mechanism Analysis For {:d} runs with status "run_success" in expnames:{:s}'.format(dftmp.shape[0],str(dftmp['expname'].unique())))
fig.update_yaxes(nticks=20,title='Time-error (SECONDS) between RTC run time and CPUTICK run time')
fig.show(renderer='browser')

# %% [markdown]
# # OTher

# %%
#mydf.to_excel(r'C:\temp\summarytable.xlsx',freeze_panes=(1,1))

# %%
#list(dfraw.groupby(['expname','unit','run']).groups.keys())[0]

# %%
dfbuilt

# %%
dfplot

# %% [markdown]
# # Plot tests

# %%
expname = '20250317_SimonGhionea_autodl';
run = 'sample_03-14-25_122320';
unit = 'PM10';
dfplot = dfraw.query('run==@run and expname==@expname and unit==@unit')
# #mkplot(dfplot);
plotly_fig = logplotter.mkplot_devicerun_detail(dfplot,dfbuilt);
#plotly_fig.update_layout(autosize=True);
plotly_fig.show(renderer='browser')

# %%
# timeline
fig = logplotter.mkplot_runs_timeline(dfruns);
fig.update_layout(autosize=False);
#fig.show(renderer='browser',config=dict(response=False))
pn_timeline = pn.pane.Plotly(fig,);
s = pn_timeline.servable();
pn.serve(s)

# %%
fig.show(renderer='browser')

# %%
fig.layout

# %%
logreader.getFilesByExpUnitRun(rootpath)
